# %%
import pandas as pd 
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as ss

# %%
aa= "C:/Users/anavi/Desktop/base_final.csv"

base= pd.read_csv(aa, index_col="Edad")
base.head()
# Out:
#      Sexo Entorno    Fam Estatus_padres  Tiempo_estudio  Reprobadas  \
# Edad
# 18      F       U  4 o +              S               2           0
# 17      F       U  4 o +              J               2           0
# 15      F       U  3 o -              J               2           3
# 15      F       U  4 o +              J               3           0
# 16      F       U  4 o +              J               2           0
#
#      Extracurriculares Universidad  Famrel  Tiempo_libre  Salir  Dalc  Falc  \
# Edad
# 18                  No          Si       4             3      4     1     1
# 17                  No          Si       5             3      3     1     1
# 15                  No          Si       4             3      2     2     3
# 15                  Si          Si       3             2      2     1     1
# 16                  No          Si       4             3      2     1     2
#
#       Faltas
# Edad
# 18         6
# 17         4
# 15        10
# 15         2
# ...

# %%
##Grafico de barras 

ss.barplot(x= base['Tiempo_estudio'], y=base['Reprobadas'])
# Out:
# <AxesSubplot:xlabel='Tiempo_estudio', ylabel='Reprobadas'>

# %%
ss.scatterplot(x=base['Faltas'], y=base['Salir'])
# Out:
# <AxesSubplot:xlabel='Faltas', ylabel='Salir'>

# %%
ss.scatterplot(x=base['Faltas'], y=base['Salir'], hue=base['Reprobadas'])
# Out:
# <AxesSubplot:xlabel='Faltas', ylabel='Salir'>

# %%
ss.regplot(x=base['Faltas'], y=base['Salir'])
# Out:
# <AxesSubplot:xlabel='Faltas', ylabel='Salir'>

# %%
ss.lmplot(x='Faltas', y='Salir', hue= 'Reprobadas', data= base)

# %%
import matplotlib as mt
from matplotlib import pyplot

mt.pyplot.figure(figsize=(14,7))

mt.pyplot.hist(base['Tiempo_libre'], color= '#808000')
mt.pyplot.xlabel('Tiempo libre')
mt.pyplot.ylabel('Frecuencia')
mt.pyplot.title ("TIEMPO LIBRE DE ESTUDIANTES")
mt.pyplot.show()
