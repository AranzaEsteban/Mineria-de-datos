# %% [markdown]
# # EQUIPO 1
#
# ## Grupo 003 (Lunes)
#    ### ESTEBAN AVALOS ARANZA ALEJANDRA 1941599
#    ### AVILA CASTRO INGRID MARIANA 1941460
#    ### CARDENAS GARCIA OSCAR ANDRES 1941600
#    ### GARCÍA SALAZAR VALERIA GUADALUPE 1850355
#    ### GONZÁLEZ PÉREZ ANA VICTORIA 1941504

# %% [markdown]
# ## Librerias

# %%
import pandas 
import numpy 
import json

# %% [markdown]
# ## Base de datos

# %%
# Csv de consumo de alcohol estudiantes de matematicas
df= pandas.read_csv("/Users/aranzaesteban/Desktop/FastFoodRestaurants.csv")                  
print(df) ##Descarga todo el archivo
print(df.shape)##Imprime la cantidad de filas y columnas
# Out:
#                     address                    city country  \
# 0               324 Main St                 Massena      US
# 1           530 Clinton Ave  Washington Court House      US
# 2      408 Market Square Dr               Maysville      US
# 3     6098 State Highway 37                 Massena      US
# 4           139 Columbus Rd                  Athens      US
# ...                     ...                     ...     ...
# 9995  3013 Peach Orchard Rd                 Augusta      US
# 9996      678 Northwest Hwy                    Cary      US
# 9997           1708 Main St                Longmont      US
# 9998      67740 Highway 111          Cathedral City      US
# 9999    5701 E La Palma Ave                 Anaheim      US
#
#                                                    keys   latitude  \
# 0                   us/ny/massena/324mainst/-1161002137  44.921300
# 1     us/oh/washingtoncourthouse/530clintonave/-7914...  39.532550
# ...

# %% [markdown]
# ## Visualizacion de datos

# %%
# Cantidad de filas, columnas
print(df.shape)
# Out:
# (10000, 10)

# %%
# 10 primeros datos de la tabla
df.head(10)
# Out:
#                          address                    city country  \
# 0                    324 Main St                 Massena      US
# 1                530 Clinton Ave  Washington Court House      US
# 2           408 Market Square Dr               Maysville      US
# 3          6098 State Highway 37                 Massena      US
# 4                139 Columbus Rd                  Athens      US
# 5                 4182 Tonya Trl                Hamilton      US
# 6                  590 S Main St               Englewood      US
# 7              401 N Jennings St                  Saluda      US
# 8                205 W Church St               Batesburg      US
# 9  2711 W. Kings Highway Ste. 18               Paragould      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# ...

# %% [markdown]
# ## Descripcion de las columnas

# %%
# Nombre de las columnas
df.columns
# Out:
# Index(['address', 'city', 'country', 'keys', 'latitude', 'longitude', 'name',
#        'postalCode', 'province', 'websites'],
#       dtype='object')

# %%
# Tipo de datos que contiene cada columna 
df.dtypes
# Out:
# address        object
# city           object
# country        object
# keys           object
# latitude      float64
# longitude     float64
# name           object
# postalCode     object
# province       object
# websites       object
# dtype: object

# %%
# Sabes si existen datos nulos en las columnas (True)
df.isnull().any()
# Out:
# address       False
# city          False
# country       False
# keys          False
# latitude      False
# longitude     False
# name          False
# postalCode    False
# province      False
# websites       True
# dtype: bool

# %% [markdown]
# ## Clasificación de datos

# %%
df.city.unique()
# Out:
# array(['Massena', 'Washington Court House', 'Maysville', ..., 'Chatham',
#        'Miles City', 'East Chicago'], dtype=object)

# %%
df.province.unique()
# Out:
# array(['NY', 'OH', 'KY', 'SC', 'AR', 'OK', 'IN', 'NC', 'TN', 'TX', 'LA',
#        'KS', 'ND', 'UT', 'GA', 'NM', 'OR', 'HI', 'VT', 'MI', 'MO', 'WI',
#        'WA', 'MS', 'NE', 'ME', 'MN', 'AL', 'IA', 'WV', 'AZ', 'SD', 'WY',
#        'IL', 'VA', 'FL', 'CA', 'MT', 'ID', 'PA', 'RI', 'NV', 'NJ', 'MA',
#        'MD', 'CO', 'NH', 'CT', 'AK', 'DE', 'DC', 'Co Spgs'], dtype=object)

# %% [markdown]
# ## Cambiar nombre de columnas

# %%
# Cambiar nombre de columnas
df.rename(columns = {"address" : "Zona"})
# Out:
#                        Zona                    city country  \
# 0               324 Main St                 Massena      US
# 1           530 Clinton Ave  Washington Court House      US
# 2      408 Market Square Dr               Maysville      US
# 3     6098 State Highway 37                 Massena      US
# 4           139 Columbus Rd                  Athens      US
# ...                     ...                     ...     ...
# 9995  3013 Peach Orchard Rd                 Augusta      US
# 9996      678 Northwest Hwy                    Cary      US
# 9997           1708 Main St                Longmont      US
# 9998      67740 Highway 111          Cathedral City      US
# 9999    5701 E La Palma Ave                 Anaheim      US
#
#                                                    keys   latitude  \
# 0                   us/ny/massena/324mainst/-1161002137  44.921300
# 1     us/oh/washingtoncourthouse/530clintonave/-7914...  39.532550
# ...

# %%
df.province.replace(to_replace = dict(NY = "NewYork", CA = "California", GA = "Georgia", OH = "Ohio", CO = "Colorado", IL = "Illinois",KY = "Kentucky"), inplace = True)

# %%
df
# Out:
#                     address                    city        country  \
# 0               324 Main St                 Massena  United States
# 1           530 Clinton Ave  Washington Court House  United States
# 2      408 Market Square Dr               Maysville  United States
# 3     6098 State Highway 37                 Massena  United States
# 4           139 Columbus Rd                  Athens  United States
# ...                     ...                     ...            ...
# 9995  3013 Peach Orchard Rd                 Augusta  United States
# 9996      678 Northwest Hwy                    Cary  United States
# 9997           1708 Main St                Longmont  United States
# 9998      67740 Highway 111          Cathedral City  United States
# 9999    5701 E La Palma Ave                 Anaheim  United States
#
#                                                    keys   latitude  \
# 0                   us/ny/massena/324mainst/-1161002137  44.921300
# ...

# %%
Ohio = df[df['province']=='Ohio']            #Hago una agrupacion en la columna sex

Ohio.to_csv('OHIO.csv', index=False)       # Se guardo la agrupacion OHIO

# %%
California = df[df['province']=='California']            #Hago una agrupacion en la columna sex

California.to_csv('CALIFORNIA.csv', index=False)       # Se guardo la agrupacion CALFORNIA

# %%
NewYork = df[df['province']=='NewYork']            #Hago una agrupacion en la columna sex

NewYork.to_csv('NEWYORK.csv', index=False)       # Se guardo la agrupacion NEWYORK

# %% [markdown]
# ## Realizar una tarea de procesamiente no mencionada en esta practica

# %%
# Eliminar todas las columnas que no contengan informacion importante
df.drop(columns=["latitude","longitude"])
# Out:
#                     address                    city        country  \
# 0               324 Main St                 Massena  United States
# 1           530 Clinton Ave  Washington Court House  United States
# 2      408 Market Square Dr               Maysville  United States
# 3     6098 State Highway 37                 Massena  United States
# 4           139 Columbus Rd                  Athens  United States
# ...                     ...                     ...            ...
# 9995  3013 Peach Orchard Rd                 Augusta  United States
# 9996      678 Northwest Hwy                    Cary  United States
# 9997           1708 Main St                Longmont  United States
# 9998      67740 Highway 111          Cathedral City  United States
# 9999    5701 E La Palma Ave                 Anaheim  United States
#
#                                                    keys  \
# 0                   us/ny/massena/324mainst/-1161002137
# ...
